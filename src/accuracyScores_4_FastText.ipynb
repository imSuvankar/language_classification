# %%
from google.colab import drive
drive.mount('gdrive/')
# Out:
# Mounted at gdrive/

# %%
# !pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.22.4)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4393198 sha256=e7e7fadfb9fb3317e8cce17d7c9bbb63270f2d7658a1cc6e60879dd9e3c5c811
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.4

# %%
import pandas
df = pandas.read_csv("/content/gdrive/MyDrive/Colab Notebooks/datasets/4_genetic_sequencing.csv")

from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

import fasttext
ft_model = fasttext.load_model('/content/gdrive/MyDrive/Colab Notebooks/additional_files/lid.176.bin')

def encode_text(text):
    text = text.replace('\n', '')
    return ft_model.get_sentence_vector(text)

train_df['text_encoded'] = train_df['seq'].apply(lambda x: encode_text(x))
test_df['text_encoded'] = test_df['seq'].apply(lambda x: encode_text(x))

import numpy as np
x_train = np.vstack(train_df['text_encoded'].values)
x_test = np.vstack(test_df['text_encoded'].values)
y_train = train_df['id']
y_test = test_df['id']

language_labels = df['id'].unique()
label_to_id = {label: i for i, label in enumerate(language_labels)}

y_train = y_train.apply(lambda x: label_to_id[x])
y_test = y_test.apply(lambda x: label_to_id[x])
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# #### 1. Using `Multinomial NB`

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(x_train.clip(min=0), y_train)

y_pred_MNB = MNB.predict(x_test.clip(min=0))

from sklearn.metrics import accuracy_score
print(f"MNB & FastText: {accuracy_score(y_test, y_pred_MNB) * 100 :.2f}%")
# Out:
# MNB & FastText: 48.74%

# %% [markdown]
# #### 2. Using `SVM`

# %%
from sklearn.svm import SVC
SVM = SVC(kernel='linear')
SVM.fit(x_train, y_train)

y_pred_SVM = SVM.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"SVM & FastText: {accuracy_score(y_test, y_pred_SVM) * 100 :.2f}%")
# Out:
# SVM & FastText: 64.47%

# %% [markdown]
# #### 3. Using `Random Forest`

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(x_train.clip(min=0), y_train)

y_pred_RF = RF.predict(x_test.clip(min=0))

from sklearn.metrics import accuracy_score
print(f"Random Forest & FastText: {accuracy_score(y_test, y_pred_RF) * 100 :.2f}%")
# Out:
# Random Forest & FastText: 62.36%

# %% [markdown]
# #### 4. Using `Gradient Boosting Classifier`

# %%
from sklearn.ensemble import GradientBoostingClassifier
GB = GradientBoostingClassifier()
GB.fit(x_train, y_train)

y_pred_GB = GB.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"Gradient Boosting Classsifier & FastText: {accuracy_score(y_test, y_pred_GB) * 100 :.2f}%")
# Out:
# Gradient Boosting Classsifier & FastText: 63.20%

# %% [markdown]
# #### 5. Using `Decision Tree Classifier`

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(x_train, y_train)

y_pred_DT = DT.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"Decision Tree Classsifier & FastText: {accuracy_score(y_test, y_pred_DT) * 100 :.2f}%")
# Out:
# Decision Tree Classsifier & FastText: 55.62%

# %% [markdown]
# #### 6. Using `K-Nearest Neighbors Classifier`

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(x_train, y_train)

y_pred_KNN = KNN.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"K-Nearest Neighbors Classifier & FastText: {accuracy_score(y_test, y_pred_KNN) * 100 :.2f}%")
# Out:
# K-Nearest Neighbors Classifier & FastText: 61.66%

# %% [markdown]
# #### 7. Using `AdaBoost Classifier`

# %%
from sklearn.ensemble import AdaBoostClassifier
ADA = AdaBoostClassifier()
ADA.fit(x_train, y_train)

y_pred_ADA = ADA.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"AdaBoost Classifier & FastText: {accuracy_score(y_test, y_pred_ADA) * 100 :.2f}%")
# Out:
# AdaBoost Classifier & FastText: 60.53%

# %% [markdown]
# #### 8. Using `Logistic Regression`

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(x_train, y_train)

y_pred_LR = LR.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"Logistic Regression & FastText: {accuracy_score(y_test, y_pred_LR) * 100 :.2f}%")
# Out:
# Logistic Regression & FastText: 63.76%

# %% [markdown]
# #### 9. Using `Extra Trees Classifier`

# %%
from sklearn.ensemble import ExtraTreesClassifier
ET = ExtraTreesClassifier()
ET.fit(x_train, y_train)

y_pred_ET = ET.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"Extra Trees Classifier & TF-IDF: {accuracy_score(y_test, y_pred_ET) * 100 :.2f}%")
# Out:
# Extra Trees Classifier & TF-IDF: 65.03%

# %% [markdown]
# #### 10. Using `Gaussian Process Regressor`

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
GPR = GaussianProcessRegressor()
GPR.fit(x_train, y_train)

y_pred_GPR = GPR.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"Gaussian Process Regressor & TF-IDF: {accuracy_score(y_test, y_pred_GPR.round()) * 100 :.2f}%")
# Out:
# Gaussian Process Regressor & TF-IDF: 22.19%

# %% [markdown]
# #### 11. Using `Ridge Classifier`

# %%
from sklearn.linear_model import RidgeClassifier
RR = RidgeClassifier()
RR.fit(x_train, y_train)

y_pred_RR = RR.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"Ridge Classifier & TF-IDF: {accuracy_score(y_test, y_pred_RR) * 100:.2f}%")
# Out:
# Ridge Classifier & TF-IDF: 64.04%

# %% [markdown]
# #### 12. Using `Elastic Net Regression`

# %%
from sklearn.linear_model import ElasticNet
EN = ElasticNet()
EN.fit(x_train, y_train)

y_pred_EN = EN.predict(x_test).round()

print(f"Elastic Net Regression & TF-IDF: {accuracy_score(y_test, y_pred_EN) * 100 :.2f}%")
# Out:
# Elastic Net Regression & TF-IDF: 45.22%

# %% [markdown]
# #### 13. Using `Multilayer Perceptron`

# %%
from sklearn.neural_network import MLPClassifier
MLP = MLPClassifier()
MLP.fit(x_train, y_train)

y_pred_MLP = MLP.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"Multilayer Perceptron & TF-IDF: {accuracy_score(y_test, y_pred_MLP) * 100 :.2f}%")
# Out:
# Multilayer Perceptron & TF-IDF: 64.04%
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# #### 14. Using `Lasso Regressor`

# %%
from sklearn.linear_model import Lasso
LASSO = Lasso()
LASSO.fit(x_train, y_train)

y_pred_LASSO = LASSO.predict(x_test)
y_pred_LASSO = [round(val) for val in y_pred_LASSO]

from sklearn.metrics import accuracy_score
print(f"Lasso Regression & TF-IDF: {accuracy_score(y_test, y_pred_LASSO) * 100 :.2f}%")
# Out:
# Lasso Regression & TF-IDF: 45.22%

# %% [markdown]
# #### 15. Using `XG Boost`

# %%
import xgboost as xgb
XGB = xgb.XGBClassifier()
XGB.fit(x_train, y_train)

y_pred_XGB = XGB.predict(x_test)

from sklearn.metrics import accuracy_score
print(f"XG Boost & TF-IDF: {accuracy_score(y_test, y_pred_XGB) * 100 :.2f}%")
# Out:
# XG Boost & TF-IDF: 64.19%

# %% [markdown]
# #### 16. Using `CNN Classifier`

# %%
import tensorflow as tf

CNN = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(128, 5, activation='relu', input_shape=(x_train.shape[1], 1)),
    tf.keras.layers.MaxPooling1D(5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(len(language_labels), activation='softmax')
])

CNN.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

x_train_cnn = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test_cnn = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

history = CNN.fit(x_train_cnn, y_train, epochs=100, batch_size=32, validation_data=(x_test_cnn, y_test))

test_loss, test_acc = CNN.evaluate(x_test_cnn, y_test)

print(f"CNN & FastText: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/100
# 259/259 [==============================] - 3s 5ms/step - loss: 1.2803 - accuracy: 0.7398 - val_loss: 0.2321 - val_accuracy: 0.9691
# Epoch 2/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.1251 - accuracy: 0.9791 - val_loss: 0.0979 - val_accuracy: 0.9773
# Epoch 3/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0722 - accuracy: 0.9840 - val_loss: 0.0756 - val_accuracy: 0.9807
# Epoch 4/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0592 - accuracy: 0.9863 - val_loss: 0.0658 - val_accuracy: 0.9821
# Epoch 5/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0515 - accuracy: 0.9874 - val_loss: 0.0611 - val_accuracy: 0.9845
# Epoch 6/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0452 - accuracy: 0.9880 - val_loss: 0.0582 - val_accuracy: 0.9836
# Epoch 7/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0422 - accuracy: 0.9898 - val_loss: 0.0517 - val_accuracy: 0.9850
# Epoch 8/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0402 - accuracy: 0.9900 - val_loss: 0.0529 - val_accuracy: 0.9855
# Epoch 9/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0367 - accuracy: 0.9900 - val_loss: 0.0511 - val_accuracy: 0.9840
# Epoch 10/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0350 - accuracy: 0.9903 - val_loss: 0.0518 - val_accuracy: 0.9879
# Epoch 11/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0321 - accuracy: 0.9911 - val_loss: 0.0466 - val_accuracy: 0.9879
# Epoch 12/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0306 - accuracy: 0.9924 - val_loss: 0.0447 - val_accuracy: 0.9903
# Epoch 13/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0301 - accuracy: 0.9923 - val_loss: 0.0433 - val_accuracy: 0.9894
# Epoch 14/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0280 - accuracy: 0.9924 - val_loss: 0.0456 - val_accuracy: 0.9865
# Epoch 15/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0267 - accuracy: 0.9927 - val_loss: 0.0440 - val_accuracy: 0.9879
# Epoch 16/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0271 - accuracy: 0.9927 - val_loss: 0.0426 - val_accuracy: 0.9869
# Epoch 17/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0265 - accuracy: 0.9935 - val_loss: 0.0418 - val_accuracy: 0.9884
# Epoch 18/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.0441 - val_accuracy: 0.9879
# Epoch 19/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.0439 - val_accuracy: 0.9874
# Epoch 20/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0242 - accuracy: 0.9931 - val_loss: 0.0396 - val_accuracy: 0.9889
# Epoch 21/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0223 - accuracy: 0.9942 - val_loss: 0.0364 - val_accuracy: 0.9913
# Epoch 22/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.0367 - val_accuracy: 0.9903
# Epoch 23/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0226 - accuracy: 0.9930 - val_loss: 0.0385 - val_accuracy: 0.9869
# Epoch 24/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0202 - accuracy: 0.9946 - val_loss: 0.0444 - val_accuracy: 0.9894
# Epoch 25/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0196 - accuracy: 0.9946 - val_loss: 0.0548 - val_accuracy: 0.9840
# Epoch 26/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.0400 - val_accuracy: 0.9889
# Epoch 27/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 0.0353 - val_accuracy: 0.9894
# Epoch 28/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.0371 - val_accuracy: 0.9898
# Epoch 29/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0174 - accuracy: 0.9958 - val_loss: 0.0365 - val_accuracy: 0.9894
# Epoch 30/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 0.0411 - val_accuracy: 0.9898
# Epoch 31/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0176 - accuracy: 0.9949 - val_loss: 0.0435 - val_accuracy: 0.9874
# Epoch 32/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0167 - accuracy: 0.9954 - val_loss: 0.0362 - val_accuracy: 0.9908
# Epoch 33/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.0456 - val_accuracy: 0.9874
# Epoch 34/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.0403 - val_accuracy: 0.9874
# Epoch 35/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.0349 - val_accuracy: 0.9918
# Epoch 36/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.0380 - val_accuracy: 0.9898
# Epoch 37/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0351 - val_accuracy: 0.9894
# Epoch 38/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.0382 - val_accuracy: 0.9884
# Epoch 39/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.0318 - val_accuracy: 0.9908
# Epoch 40/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.0394 - val_accuracy: 0.9894
# Epoch 41/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.0431 - val_accuracy: 0.9879
# Epoch 42/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0386 - val_accuracy: 0.9889
# Epoch 43/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.0342 - val_accuracy: 0.9918
# Epoch 44/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0404 - val_accuracy: 0.9894
# Epoch 45/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.0353 - val_accuracy: 0.9894
# Epoch 46/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0324 - val_accuracy: 0.9908
# Epoch 47/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0381 - val_accuracy: 0.9908
# Epoch 48/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0306 - val_accuracy: 0.9898
# Epoch 49/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0432 - val_accuracy: 0.9913
# Epoch 50/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.0347 - val_accuracy: 0.9913
# Epoch 51/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0391 - val_accuracy: 0.9903
# Epoch 52/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0366 - val_accuracy: 0.9923
# Epoch 53/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0382 - val_accuracy: 0.9898
# Epoch 54/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0365 - val_accuracy: 0.9894
# Epoch 55/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0350 - val_accuracy: 0.9889
# Epoch 56/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0385 - val_accuracy: 0.9884
# Epoch 57/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0309 - val_accuracy: 0.9903
# Epoch 58/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0371 - val_accuracy: 0.9913
# Epoch 59/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0414 - val_accuracy: 0.9913
# Epoch 60/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.0378 - val_accuracy: 0.9903
# Epoch 61/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0350 - val_accuracy: 0.9898
# Epoch 62/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.0359 - val_accuracy: 0.9918
# Epoch 63/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0407 - val_accuracy: 0.9913
# Epoch 64/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0340 - val_accuracy: 0.9927
# Epoch 65/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0328 - val_accuracy: 0.9913
# Epoch 66/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0506 - val_accuracy: 0.9903
# Epoch 67/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0377 - val_accuracy: 0.9932
# Epoch 68/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0356 - val_accuracy: 0.9903
# Epoch 69/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0363 - val_accuracy: 0.9879
# Epoch 70/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0365 - val_accuracy: 0.9913
# Epoch 71/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0417 - val_accuracy: 0.9903
# Epoch 72/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0378 - val_accuracy: 0.9927
# Epoch 73/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0428 - val_accuracy: 0.9908
# Epoch 74/100
# 259/259 [==============================] - 4s 17ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0384 - val_accuracy: 0.9908
# Epoch 75/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0365 - val_accuracy: 0.9932
# Epoch 76/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0514 - val_accuracy: 0.9908
# Epoch 77/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.0399 - val_accuracy: 0.9918
# Epoch 78/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.0429 - val_accuracy: 0.9889
# Epoch 79/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0044 - accuracy: 0.9983 - val_loss: 0.0474 - val_accuracy: 0.9898
# Epoch 80/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0386 - val_accuracy: 0.9923
# Epoch 81/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0523 - val_accuracy: 0.9903
# Epoch 82/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.0394 - val_accuracy: 0.9927
# Epoch 83/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.0374 - val_accuracy: 0.9913
# Epoch 84/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0543 - val_accuracy: 0.9879
# Epoch 85/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0580 - val_accuracy: 0.9898
# Epoch 86/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0375 - val_accuracy: 0.9923
# Epoch 87/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.0410 - val_accuracy: 0.9908
# Epoch 88/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0416 - val_accuracy: 0.9918
# Epoch 89/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0403 - val_accuracy: 0.9894
# Epoch 90/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0398 - val_accuracy: 0.9908
# Epoch 91/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0513 - val_accuracy: 0.9903
# Epoch 92/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0491 - val_accuracy: 0.9879
# Epoch 93/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0407 - val_accuracy: 0.9927
# Epoch 94/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0382 - val_accuracy: 0.9908
# Epoch 95/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0481 - val_accuracy: 0.9884
# Epoch 96/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.0408 - val_accuracy: 0.9923
# Epoch 97/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0392 - val_accuracy: 0.9918
# Epoch 98/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0434 - val_accuracy: 0.9918
# Epoch 99/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0413 - val_accuracy: 0.9937
# Epoch 100/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0398 - val_accuracy: 0.9937
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0398 - accuracy: 0.9937
# CNN & FastText: 99.37%
